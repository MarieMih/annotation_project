# %%
import os, sys
import matplotlib.pyplot as plt

# %%
# Function to count lines containing ">" in a file
def count_lines_with_char(file_path, char=">"):
    count = 0
    with open(file_path, 'r') as file:
        for line in file:
            if char in line:
                count += 1
    return count

# Directory containing the files (adjust the path as needed)
directory = "distr_50"

# List to store file numbers and corresponding counts
file_numbers = []
line_counts = []

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith("rep_seq.fasta"):  # Adjust the extension as needed
        # Extract the number from the filename (assuming filenames are in format like file1.txt)
        file_number = int(''.join(filter(str.isdigit, filename)))
        
        # Full path to the file
        file_path = os.path.join(directory, filename)
        
        # Count lines containing ">"
        count = count_lines_with_char(file_path)
        
        # Append the results to the lists
        file_numbers.append(file_number)
        line_counts.append(count)

# %%
file_numbers
# Out:
# [83,
#  84,
#  57,
#  68,
#  92,
#  91,
#  70,
#  95,
#  54,
#  64,
#  61,
#  77,
#  89,
#  96,
#  56,
#  62,
#  63,
#  88,
#  75,
#  86,
#  98,
#  93,
#  90,
#  80,
#  74,
#  66,
#  65,
#  53,
#  82,
#  78,
#  76,
#  99,
#  81,
#  79,
#  85,
#  73,
#  51,
#  52,
#  71,
#  94,
#  58,
#  97,
#  50,
#  72,
#  67,
#  69,
#  55,
#  87,
#  60,
#  59]

# %%
line_counts
# Out:
# [29330, 28142, 35084, 38557, 90659, 52247, 30825, 27164, 69616, 32632, 43798]

# %%
min(file_numbers)
# Out:
# 50

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(file_numbers, line_counts, marker='o', ls = "")
plt.xlabel('Identity')
plt.ylabel('Number of clusters')
plt.title('Number of clusters')
plt.grid(True)

# Save the plot to a file
output_file = 'plot_'+ str(min(file_numbers)) + '_' + str(max(file_numbers)) + 'coli' +'.png'  # Change the file name and extension as needed
plt.savefig(output_file)

print(f"Plot has been saved to '{output_file}'")
# Out:
# Plot has been saved to 'plot_50_100coli.png'
